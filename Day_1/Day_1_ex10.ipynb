# %%
import tensorflow as tf

# %%
tf.set_random_seed(777)

# %%
x_train = [1, 2, 3]
y_train = [1, 2, 3]

# %%
W = tf.Variable(tf.random_normal([1]), name = "weight")
b = tf.Variable(tf.random_normal([1]), name = "bias")

# %%
hypothesis = x_train * W + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
train = tf.train.GradientDescentOptimizer(learning_rate = 0.01).minimize(cost)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(2001):
        _, cost_val, W_val, b_val = sess.run([train, cost, W, b])
        
        if step % 20 == 0:
            print(step, cost_val, W_val, b_val)
# Out:
# 0 3.5240757 [2.2086694] [-0.8204183]
# 20 0.19749959 [1.5425726] [-1.0498911]
# 40 0.15214373 [1.4590572] [-1.0260717]
# 60 0.13793248 [1.4319589] [-0.9802801]
# 80 0.12527026 [1.4111322] [-0.934442]
# 100 0.11377239 [1.3917603] [-0.8905485]
# 120 0.103329934 [1.3733444] [-0.8486981]
# 140 0.09384587 [1.3557981] [-0.8088127]
# 160 0.08523238 [1.339077] [-0.7708015]
# 180 0.0774094 [1.3231416] [-0.7345767]
# 200 0.07030449 [1.3079553] [-0.7000544]
# 220 0.06385169 [1.2934824] [-0.66715455]
# 240 0.057991147 [1.2796899] [-0.6358009]
# 260 0.052668482 [1.2665455] [-0.60592055]
# 280 0.047834355 [1.2540188] [-0.57744455]
# 300 0.043443944 [1.2420808] [-0.55030674]
# 320 0.039456483 [1.230704] [-0.5244443]
# 340 0.03583498 [1.2198616] [-0.49979722]
# 360 0.03254589 [1.2095289] [-0.47630855]
# 380 0.029558683 [1.1996818] [-0.4539237]
# 400 0.026845662 [1.1902975] [-0.43259096]
# 420 0.024381677 [1.1813543] [-0.4122609]
# 440 0.022143835 [1.1728313] [-0.3928862]
# 460 0.02011138 [1.1647089] [-0.37442195]
# 480 0.018265486 [1.1569681] [-0.35682547]
# 500 0.016589014 [1.1495912] [-0.34005603]
# 520 0.015066385 [1.1425607] [-0.32407463]
# 540 0.013683546 [1.135861] [-0.30884418]
# 560 0.012427603 [1.1294761] [-0.2943296]
# 580 0.011286956 [1.1233914] [-0.28049716]
# 600 0.010250981 [1.1175922] [-0.26731485]
# 620 0.009310112 [1.1120659] [-0.25475204]
# 640 0.008455603 [1.1067992] [-0.24277969]
# 660 0.0076795216 [1.1017802] [-0.23137005]
# 680 0.0069746617 [1.0969968] [-0.22049649]
# 700 0.006334486 [1.0924382] [-0.21013394]
# 720 0.0057530873 [1.088094] [-0.20025837]
# 740 0.005225048 [1.0839541] [-0.19084705]
# 760 0.0047454657 [1.0800083] [-0.18187788]
# 780 0.004309909 [1.0762483] [-0.17333023]
# 800 0.003914328 [1.072665] [-0.1651844]
# 820 0.003555062 [1.06925] [-0.15742144]
# 840 0.0032287624 [1.0659956] [-0.15002325]
# 860 0.0029324212 [1.062894] [-0.14297272]
# 880 0.002663277 [1.0599382] [-0.13625367]
# 900 0.0024188298 [1.0571213] [-0.12985022]
# 920 0.002196817 [1.0544368] [-0.12374771]
# 940 0.0019951796 [1.0518785] [-0.11793201]
# 960 0.0018120552 [1.0494404] [-0.11238959]
# 980 0.0016457397 [1.0471169] [-0.10710769]
# 1000 0.0014946844 [1.0449026] [-0.10207403]
# 1020 0.001357506 [1.0427924] [-0.09727701]
# 1040 0.0012329047 [1.0407815] [-0.0927054]
# 1060 0.0011197398 [1.0388646] [-0.08834853]
# 1080 0.0010169642 [1.0370382] [-0.08419646]
# 1100 0.0009236282 [1.0352975] [-0.08023955]
# 1120 0.000838855 [1.0336386] [-0.07646856]
# 1140 0.000761858 [1.0320578] [-0.07287483]
# 1160 0.00069193525 [1.0305511] [-0.06944999]
# 1180 0.0006284237 [1.0291152] [-0.06618603]
# 1200 0.0005707424 [1.027747] [-0.06307549]
# 1220 0.0005183569 [1.026443] [-0.06011118]
# 1240 0.0004707781 [1.0252002] [-0.05728615]
# 1260 0.00042757162 [1.024016] [-0.05459393]
# 1280 0.00038833017 [1.0228873] [-0.05202826]
# 1300 0.00035268549 [1.0218118] [-0.04958317]
# 1320 0.00032031667 [1.020787] [-0.04725303]
# 1340 0.00029091907 [1.01981] [-0.04503256]
# 1360 0.00026421473 [1.0188788] [-0.04291612]
# 1380 0.00023996418 [1.0179915] [-0.04089916]
# 1400 0.00021793954 [1.0171461] [-0.03897704]
# 1420 0.00019793601 [1.0163403] [-0.03714526]
# 1440 0.00017976847 [1.0155723] [-0.03539959]
# 1460 0.000163269 [1.0148405] [-0.03373594]
# 1480 0.00014828402 [1.014143] [-0.03215046]
# 1500 0.0001346743 [1.0134784] [-0.03063953]
# 1520 0.00012231102 [1.0128449] [-0.02919954]
# 1540 0.00011108658 [1.0122414] [-0.02782728]
# 1560 0.00010089126 [1.0116659] [-0.02651951]
# 1580 9.163081e-05 [1.0111177] [-0.02527316]
# 1600 8.3219806e-05 [1.0105953] [-0.02408545]
# 1620 7.558181e-05 [1.0100973] [-0.0229535]
# 1640 6.864449e-05 [1.0096227] [-0.02187471]
# 1660 6.234351e-05 [1.0091705] [-0.02084666]
# 1680 5.6621455e-05 [1.0087395] [-0.01986697]
# 1700 5.1424246e-05 [1.0083288] [-0.01893329]
# 1720 4.6703455e-05 [1.0079373] [-0.01804345]
# 1740 4.2417694e-05 [1.0075643] [-0.01719548]
# 1760 3.8524722e-05 [1.0072088] [-0.01638733]
# 1780 3.4988974e-05 [1.00687] [-0.0156172]
# 1800 3.1776857e-05 [1.0065471] [-0.01488321]
# 1820 2.8860317e-05 [1.0062394] [-0.01418371]
# 1840 2.621177e-05 [1.0059463] [-0.01351713]
# 1860 2.3805274e-05 [1.0056667] [-0.01288191]
# 1880 2.1620881e-05 [1.0054004] [-0.01227649]
# 1900 1.963668e-05 [1.0051466] [-0.01169953]
# 1920 1.7833701e-05 [1.0049047] [-0.01114966]
# 1940 1.6197004e-05 [1.0046743] [-0.01062568]
# 1960 1.4710833e-05 [1.0044547] [-0.01012636]
# 1980 1.3361122e-05 [1.0042454] [-0.00965053]
# 2000 1.2134453e-05 [1.0040458] [-0.00919706]
